# %%
import json
with open("/Users/cwang138/Downloads/5b47b350337d4a3629076f2c.json", "r") as f:
    mapping = json.load(f)

# %%
fragility_ids = []
for e in mapping["mappings"]:
    for key, value in e["entry"].items():
        if value not in fragility_ids:
            fragility_ids.append(value)

# %%
fragility_ids
# Out:
# ['5b47b34f337d4a3629076470',
#  '5b47b34f337d4a3629075de9',
#  '5b47b350337d4a3629076e1f',
#  '5b47b34f337d4a3629075a90',
#  '5b47b350337d4a3629076e27',
#  '5b47b350337d4a36290769b6',
#  '5b47b350337d4a3629076de4',
#  '5b47b34f337d4a36290755b4',
#  '5b47b34f337d4a36290755b5',
#  '5b47b34f337d4a3629075a97',
#  '5b47b34f337d4a3629076472',
#  '5b47b34f337d4a3629075df5',
#  '5b47b350337d4a3629076e23',
#  '5b47b350337d4a36290769d2',
#  '5b47b350337d4a3629076e25',
#  '5b47b350337d4a36290769b9',
#  '5b47b350337d4a3629076de8',
#  '5b47b34f337d4a36290755ad',
#  '5b47b350337d4a3629076e2d',
#  '5b47b34f337d4a36290755b6',
#  '5b47b34f337d4a36290755b1',
#  '5b47b34e337d4a36290754a0',
#  '5b47b350337d4a36290769d0',
#  '5b47b34f337d4a36290755ae',
#  '5b47b350337d4a3629076e2a',
#  '5b47b34f337d4a362907647b',
#  '5b47b34f337d4a3629075deb',
#  '5b47b350337d4a3629076e20',
#  '5b47b350337d4a36290769b8',
#  '5b47b350337d4a3629076e21',
#  '5b47b350337d4a36290769b7',
#  '5b47b350337d4a3629076de1',
# ...

# %% [markdown]
# ### revert

# %%
# copy those above from tst
from pymongo import MongoClient
from bson.objectid import ObjectId

tst_uri = "mongodb://localhost:27017/?connectTimeoutMS=10000"
tst_client = MongoClient(tst_uri)
tst_db = tst_client['dfr3db']
tst_fragility_collection = tst_db['FragilitySet']

dev_uri = "mongodb://root:incorerocks@localhost:27019/?connectTimeoutMS=10000&authSource=admin&authMechanism=SCRAM-SHA-256"
dev_client = MongoClient(dev_uri)
dev_db = dev_client['dfr3db']
dev_fragility_collection = dev_db['FragilitySet']

for fragility_id in fragility_ids:
    dev_doc = dev_fragility_collection.find_one({"_id": ObjectId(fragility_id)})
    tst_doc = tst_fragility_collection.find_one({"_id": ObjectId(fragility_id)})
    dev_fragility_collection.replace_one({'_id': dev_doc['_id']}, tst_doc)

# %%
from refactoring_dfr3_schema import convert_fragility_sets
from pymongo import MongoClient

# %%
# uri = "mongodb://localhost:27017/?connectTimeoutMS=10000"
uri = "mongodb://root:incorerocks@localhost:27019/?connectTimeoutMS=10000&authSource=admin&authMechanism=SCRAM-SHA-256"
client = MongoClient(uri)

db = client['dfr3db']
fragility_collection = db['FragilitySet']

# local examples
# fragility_ids = [
#     "5b47c13d337d4a381cdf90a6",  # standard
#     "5b47b2d8337d4a36187c7111",  # period standard with 0.2 sec sa
#     "5b47b2d8337d4a36187c6c05",  # period building
#     "5ed915895b6166000155d6ca",  # conditional
#     "5b47ba6f337d4a3721059370",  # custom expression
#     "5ed6bfc35b6166000155d0d9",  # parametric
# ]
new_ids = convert_fragility_sets(fragility_collection, fragility_ids, save_exp=False, replace=True,
                                 insert_new=False)
# Out:
# update: 5b47b34f337d4a3629076470
# update: 5b47b34f337d4a3629075de9
# update: 5b47b350337d4a3629076e1f
# update: 5b47b34f337d4a3629075a90
# update: 5b47b350337d4a3629076e27
# update: 5b47b350337d4a36290769b6
# update: 5b47b350337d4a3629076de4
# update: 5b47b34f337d4a36290755b4
# update: 5b47b34f337d4a36290755b5
# update: 5b47b34f337d4a3629075a97
# update: 5b47b34f337d4a3629076472
# update: 5b47b34f337d4a3629075df5
# update: 5b47b350337d4a3629076e23
# update: 5b47b350337d4a36290769d2
# update: 5b47b350337d4a3629076e25
# update: 5b47b350337d4a36290769b9
# update: 5b47b350337d4a3629076de8
# update: 5b47b34f337d4a36290755ad
# update: 5b47b350337d4a3629076e2d
# update: 5b47b34f337d4a36290755b6
# update: 5b47b34f337d4a36290755b1
# update: 5b47b34e337d4a36290754a0
# update: 5b47b350337d4a36290769d0
# update: 5b47b34f337d4a36290755ae
# update: 5b47b350337d4a3629076e2a
# update: 5b47b34f337d4a362907647b
# update: 5b47b34f337d4a3629075deb
# update: 5b47b350337d4a3629076e20
# ...

# %%
print(new_ids)
